# %%
# Import required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# Load dataset
df= pd.read_csv('https://raw.githubusercontent.com/mohittomar2008/Micro-Credit-Defaulter/main/Data%20file.csv', index_col=0)

# %%
# Top 5 records
df.head(5)
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 1      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 2      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 3      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 4      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 5      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 1                2.0                0.0              1539  ...
# 2               20.0                0.0              5787  ...
# 3                3.0                0.0              1539  ...
# 4               41.0                0.0               947  ...
# 5                4.0                0.0              2309  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 1              6.0                 0.0          2.0            12
# 2             12.0                 0.0          1.0            12
# 3              6.0                 0.0          1.0             6
# 4              6.0                 0.0          2.0            12
# 5              6.0                 0.0          7.0            42
#
#    maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 1                6                 0.0  29.000000  29.000000      UPW
# 2               12                 0.0   0.000000   0.000000      UPW
# 3                6                 0.0   0.000000   0.000000      UPW
# 4                6                 0.0   0.000000   0.000000      UPW
# 5                6                 0.0   2.333333   2.333333      UPW
#
#         pdate
# 1  2016-07-20
# 2  2016-08-10
# 3  2016-08-19
# 4  2016-06-06
# 5  2016-06-22
#
# [5 rows x 36 columns]

# %%
# Random sample of 5 records
df.sample(5)
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 204734      1  86499I70788   207.0    132.432000    132.432000   -542.70
# 76922       1  67440I70377   256.0     14.552000     14.552000    362.08
# 100765      1  83497I70371   349.0      6.541333      6.541333    183.76
# 190701      0  65219I85330   140.0    105.949333    122.310000    115.56
# 1469        1  10967I89237  1932.0   4385.341000   4478.410000    516.99
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 204734   -542.70               19.0                0.0               773  ...
# 76922     362.08                0.0                0.0                 0  ...
# 100765    183.76               10.0                0.0               773  ...
# 190701    159.56                2.0                0.0               770  ...
# 1469     1567.56                7.0                0.0              1539  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 204734              6.0                 0.0          1.0             6
# 76922               6.0                 0.0          1.0             6
# 100765              6.0                 0.0          2.0            12
# 190701              6.0                 0.0          3.0            18
# 1469                6.0                 0.0          3.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 204734                6                 0.0        0.0        0.0      UPW
# 76922                 6                 0.0        0.0        0.0      UPW
# 100765                6                 0.0        5.5        5.5      UPW
# 190701                6                 0.0        0.0       17.5      UPW
# 1469                  6                 0.0        0.0        3.5      UPW
#
#              pdate
# 204734  2016-06-18
# 76922   2016-06-08
# 100765  2016-06-08
# 190701  2016-07-22
# 1469    2016-07-27
#
# [5 rows x 36 columns]

# %%
# Last 5 records
df.tail(5)
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 209589      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209590      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209591      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209592      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209593      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  \
# 209589   1089.19                1.0                0.0              4048  ...
# 209590   1728.36                4.0                0.0               773  ...
# 209591   8893.20                3.0                0.0              1539  ...
# 209592    984.58                2.0               38.0               773  ...
# 209593    631.20               13.0                0.0              7526  ...
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 209589              6.0                 0.0          2.0            12
# 209590              6.0                 0.0          3.0            18
# 209591             12.0                 0.0          6.0            54
# 209592             12.0                 0.0          3.0            24
# 209593             12.0                 0.0          2.0            18
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90  pcircle  \
# 209589                6                 0.0        1.0   1.000000      UPW
# 209590                6                 0.0        1.0   1.000000      UPW
# 209591               12                 0.0        4.0   3.833333      UPW
# 209592               12                 0.0        0.0  10.500000      UPW
# 209593               12                 0.0        0.0   0.000000      UPW
#
#              pdate
# 209589  2016-06-17
# 209590  2016-06-12
# 209591  2016-07-29
# 209592  2016-07-25
# 209593  2016-07-07
#
# [5 rows x 36 columns]

# %%
print('Our Dataset size is  ', df.shape)
# Out:
# Our Dataset size is   (209593, 36)

# %%
# hgow data look like
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 209593 entries, 1 to 209593
# Data columns (total 36 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
#  14  medianmarechprebal30  209593 non-null  float64
#  15  cnt_ma_rech90         209593 non-null  int64
#  16  fr_ma_rech90          209593 non-null  int64
#  17  sumamnt_ma_rech90     209593 non-null  int64
#  18  medianamnt_ma_rech90  209593 non-null  float64
#  19  medianmarechprebal90  209593 non-null  float64
#  20  cnt_da_rech30         209593 non-null  float64
#  21  fr_da_rech30          209593 non-null  float64
#  22  cnt_da_rech90         209593 non-null  int64
#  23  fr_da_rech90          209593 non-null  int64
#  24  cnt_loans30           209593 non-null  int64
#  25  amnt_loans30          209593 non-null  int64
#  26  maxamnt_loans30       209593 non-null  float64
#  27  medianamnt_loans30    209593 non-null  float64
#  28  cnt_loans90           209593 non-null  float64
#  29  amnt_loans90          209593 non-null  int64
#  30  maxamnt_loans90       209593 non-null  int64
#  31  medianamnt_loans90    209593 non-null  float64
#  32  payback30             209593 non-null  float64
#  33  payback90             209593 non-null  float64
#  34  pcircle               209593 non-null  object
#  35  pdate                 209593 non-null  object
# dtypes: float64(21), int64(12), object(3)
# memory usage: 59.2+ MB

# %% [markdown]
# ### we donot have any Null values in the dataset

# %%
#Total records= 36

[x for x in df.columns if df[x].dtypes=='O']
# Out:
# ['msisdn', 'pcircle', 'pdate']

# %%
len([x for x in df.columns if df[x].dtypes!='O'])
# Out:
# 33

# %% [markdown]
# Out of 36 we have 33 Numerical features while 3 categorical features

# %% [markdown]
# ### Verify for any Missing Values

# %%
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pcircle                 0
# pdate                   0
# dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## We donot have any Missing values in our dataset

# %%
pd.set_option('display.max_columns',None)

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# 25%       280.420000     300.260000           1.000000           0.000000
# 50%      1083.570000    1334.000000           3.000000           0.000000
# 75%      3356.940000    4201.790000           7.000000           0.000000
# max    198926.110000  200148.110000      998650.377733      999171.809410
#
#        last_rech_amt_ma  cnt_ma_rech30   fr_ma_rech30  sumamnt_ma_rech30  \
# count     209593.000000  209593.000000  209593.000000      209593.000000
# mean        2064.452797       3.978057    3737.355121        7704.501157
# std         2370.786034       4.256090   53643.625172       10139.621714
# min            0.000000       0.000000       0.000000           0.000000
# 25%          770.000000       1.000000       0.000000        1540.000000
# 50%         1539.000000       3.000000       2.000000        4628.000000
# 75%         2309.000000       5.000000       6.000000       10010.000000
# max        55000.000000     203.000000  999606.368132      810096.000000
#
#        medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# count         209593.000000         209593.000000   209593.00000
# mean            1812.817952           3851.927942        6.31543
# std             2070.864620          54006.374433        7.19347
# min                0.000000           -200.000000        0.00000
# 25%              770.000000             11.000000        2.00000
# 50%             1539.000000             33.900000        4.00000
# 75%             1924.000000             83.000000        8.00000
# max            55000.000000         999479.419319      336.00000
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# count  209593.000000      209593.000000         209593.000000
# mean        7.716780       12396.218352           1864.595821
# std        12.590251       16857.793882           2081.680664
# min         0.000000           0.000000              0.000000
# 25%         0.000000        2317.000000            773.000000
# 50%         2.000000        7226.000000           1539.000000
# 75%         8.000000       16000.000000           1924.000000
# max        88.000000      953036.000000          55000.000000
#
#        medianmarechprebal90  cnt_da_rech30   fr_da_rech30  cnt_da_rech90  \
# count         209593.000000  209593.000000  209593.000000  209593.000000
# mean              92.025541     262.578110    3749.494447       0.041495
# std              369.215658    4183.897978   53885.414979       0.397556
# min             -200.000000       0.000000       0.000000       0.000000
# 25%               14.600000       0.000000       0.000000       0.000000
# 50%               36.000000       0.000000       0.000000       0.000000
# 75%               79.310000       0.000000       0.000000       0.000000
# max            41456.500000   99914.441420  999809.240107      38.000000
#
#         fr_da_rech90    cnt_loans30   amnt_loans30  maxamnt_loans30  \
# count  209593.000000  209593.000000  209593.000000    209593.000000
# mean        0.045712       2.758981      17.952021       274.658747
# std         0.951386       2.554502      17.379741      4245.264648
# min         0.000000       0.000000       0.000000         0.000000
# 25%         0.000000       1.000000       6.000000         6.000000
# 50%         0.000000       2.000000      12.000000         6.000000
# 75%         0.000000       4.000000      24.000000         6.000000
# max        64.000000      50.000000     306.000000     99864.560864
#
#        medianamnt_loans30    cnt_loans90   amnt_loans90  maxamnt_loans90  \
# count       209593.000000  209593.000000  209593.000000    209593.000000
# mean             0.054029      18.520919      23.645398         6.703134
# std              0.218039     224.797423      26.469861         2.103864
# min              0.000000       0.000000       0.000000         0.000000
# 25%              0.000000       1.000000       6.000000         6.000000
# 50%              0.000000       2.000000      12.000000         6.000000
# 75%              0.000000       5.000000      30.000000         6.000000
# max              3.000000    4997.517944     438.000000        12.000000
#
#        medianamnt_loans90      payback30      payback90
# count       209593.000000  209593.000000  209593.000000
# mean             0.046077       3.398826       4.321485
# std              0.200692       8.813729      10.308108
# min              0.000000       0.000000       0.000000
# 25%              0.000000       0.000000       0.000000
# 50%              0.000000       0.000000       1.666667
# 75%              0.000000       3.750000       4.500000
# max              3.000000     171.500000     171.500000

# %% [raw]
# SOme features have negative values within like:
#     aon:  age on celular network
#     daily_decr30 : Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)
#     daily_decr90 : Daily amount spent from main account, averaged over last 90 days (in Indonesian Rupiah)
#     rental30     : Average main account balance over last 30 days
#     rental90     : Average main account balance over last 90 days
#     last_rech_date_ma : Number of days till last recharge of main account
#     last_rech_date_da : Number of days till last recharge of data account
#     medianmarechprebal30  : Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)
#     medianmarechprebal90 : Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)
#
# These features are havinf days/time which cannot be in negative values. Lets explore further.

# %%
df['aon'].min()
# Out:
# -48.0

# %%
df[df['aon']<0]
# Out:
#         label       msisdn   aon  daily_decr30  daily_decr90  rental30  \
# 31          1  70130I90843 -42.0      8.864333      8.864333    780.71
# 198         1  46858I90841 -36.0     32.075333     32.075333   1557.53
# 323         1  03027I70379 -37.0      9.160000      9.160000    203.04
# 505         1  75670I84458 -36.0     11.470333     11.470333     40.04
# 604         1  58495I89235 -35.0     12.474000     12.474000   1823.08
# ...       ...          ...   ...           ...           ...       ...
# 208717      1  10162I90589 -34.0     19.260000     19.260000    714.15
# 209122      1  65511I84450 -18.0    700.580000    700.600000   1057.72
# 209241      1  34896I70375 -28.0     10.640000     10.640000    133.35
# 209422      1  51717I84459 -44.0      7.166667      7.166667    368.55
# 209515      0  50508I70786  -2.0   1030.000000   1030.000000    634.91
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 31        780.71      780195.497093                0.0               773
# 198      1557.53           1.000000                0.0              1539
# 323       203.04           1.000000                0.0               770
# 505        40.04           1.000000                0.0               770
# 604      1823.08           1.000000                0.0              1539
# ...          ...                ...                ...               ...
# 208717    714.15           1.000000                0.0               773
# 209122   1090.76           1.000000                0.0               770
# 209241    133.35           1.000000                0.0               770
# 209422    368.55           1.000000                0.0               773
# 209515    634.91           1.000000                0.0              1539
#
#         cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 31                  2          10.0              946.0                 473.0
# 198                 1           0.0             1539.0                1539.0
# 323                 2          16.0              943.0                 471.5
# 505                 1           0.0              770.0                 770.0
# 604                 1           0.0             1539.0                1539.0
# ...               ...           ...                ...                   ...
# 208717              1           0.0              773.0                 773.0
# 209122              1           0.0              770.0                 770.0
# 209241              1           0.0              770.0                 770.0
# 209422              1           0.0              773.0                 773.0
# 209515              1           0.0             1539.0                1539.0
#
#         medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 31                      1.80              3            32               2666
# 198                     4.87              1             0               1539
# 323                    12.30              2            16                943
# 505                     8.40              1             0                770
# 604                    80.20              1             0               1539
# ...                      ...            ...           ...                ...
# 208717                  4.50              1             0                773
# 209122                 25.00              1             0                770
# 209241                 54.00              1             0                770
# 209422                 29.00              1             0                773
# 209515                 17.70              1             0               1539
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  \
# 31                     773.0                  0.30            0.0
# 198                   1539.0                  4.87            0.0
# 323                    471.5                 12.30            0.0
# 505                    770.0                  8.40            0.0
# 604                   1539.0                 80.20            0.0
# ...                      ...                   ...            ...
# 208717                 773.0                  4.50            0.0
# 209122                 770.0                 25.00            0.0
# 209241                 770.0                 54.00            0.0
# 209422                 773.0                 29.00            0.0
# 209515                1539.0                 17.70            0.0
#
#         fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# 31               0.0              0             0            1             6
# 198              0.0              0             0            1             6
# 323              0.0              0             0            1             6
# 505              0.0              0             0            1             6
# 604              0.0              0             0            1             6
# ...              ...            ...           ...          ...           ...
# 208717           0.0              0             0            1             6
# 209122           0.0              0             0            1             6
# 209241           0.0              0             0            1             6
# 209422           0.0              0             0            1             6
# 209515           0.0              0             0            1             6
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 31                  6.0                 1.0     1.000000             6
# 198                 6.0                 0.0     1.000000             6
# 323                 6.0                 0.0     1.000000             6
# 505                 6.0                 0.0  3565.786503             6
# 604                 6.0                 0.0     1.000000             6
# ...                 ...                 ...          ...           ...
# 208717              6.0                 0.0     1.000000             6
# 209122              6.0                 0.0     1.000000             6
# 209241              6.0                 0.0     1.000000             6
# 209422              6.0                 0.0     1.000000             6
# 209515              6.0                 1.0     1.000000             6
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90 pcircle  \
# 31                    6                 1.0        0.0        0.0     UPW
# 198                   6                 0.0        0.0        0.0     UPW
# 323                   6                 0.0        0.0        0.0     UPW
# 505                   6                 0.0        0.0        0.0     UPW
# 604                   6                 0.0        0.0        0.0     UPW
# ...                 ...                 ...        ...        ...     ...
# 208717                6                 0.0        0.0        0.0     UPW
# 209122                6                 0.0        0.0        0.0     UPW
# 209241                6                 0.0        0.0        0.0     UPW
# 209422                6                 0.0        0.0        0.0     UPW
# 209515                6                 1.0        0.0        0.0     UPW
#
#              pdate
# 31      2016-06-07
# 198     2016-06-13
# 323     2016-06-12
# 505     2016-06-13
# 604     2016-06-14
# ...            ...
# 208717  2016-06-15
# 209122  2016-07-01
# 209241  2016-06-21
# 209422  2016-06-05
# 209515  2016-07-17
#
# [1539 rows x 36 columns]

# %% [markdown]
# ## Check for any duplicate records

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#         label       msisdn    aon  daily_decr30  daily_decr90  rental30  \
# 198195      1  82741I90849  367.0   3136.666667   3136.666667   3320.95
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 198195   3320.95                1.0                0.0               770
#
#         cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 198195              5           1.0             8666.0                1539.0
#
#         medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 198195                  96.0              5             1               8666
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  \
# 198195                1539.0                  96.0            0.0
#
#         fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# 198195           0.0              0             0            4            24
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 198195              6.0                 0.0          4.0            24
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90 pcircle  \
# 198195                6                 0.0      42.75      42.75     UPW
#
#              pdate
# 198195  2016-07-23

# %%
df[df['msisdn']=='82741I90849']
# Out:
#         label       msisdn    aon  daily_decr30  daily_decr90  rental30  \
# 51094       1  82741I90849  367.0   3136.666667   3136.666667   3320.95
# 198195      1  82741I90849  367.0   3136.666667   3136.666667   3320.95
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 51094    3320.95                1.0                0.0               770
# 198195   3320.95                1.0                0.0               770
#
#         cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 51094               5           1.0             8666.0                1539.0
# 198195              5           1.0             8666.0                1539.0
#
#         medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 51094                   96.0              5             1               8666
# 198195                  96.0              5             1               8666
#
#         medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  \
# 51094                 1539.0                  96.0            0.0
# 198195                1539.0                  96.0            0.0
#
#         fr_da_rech30  cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  \
# 51094            0.0              0             0            4            24
# 198195           0.0              0             0            4            24
#
#         maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 51094               6.0                 0.0          4.0            24
# 198195              6.0                 0.0          4.0            24
#
#         maxamnt_loans90  medianamnt_loans90  payback30  payback90 pcircle  \
# 51094                 6                 0.0      42.75      42.75     UPW
# 198195                6                 0.0      42.75      42.75     UPW
#
#              pdate
# 51094   2016-07-23
# 198195  2016-07-23

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (209592, 36)

# %% [markdown]
# ## Remove/replace negative values

# %%
col=['aon','daily_decr30','daily_decr90','rental30','rental90','last_rech_date_ma','last_rech_date_da','medianmarechprebal30','medianmarechprebal90']

# %%
df[col]=df[col].apply(abs)

# %% [markdown]
# # Lets perform some EDA

# %% [markdown]
# ### Target Feature:  label

# %%
sns.countplot(df['label'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
df['label'].value_counts(normalize=True)*100
# Out:
# 1    87.517653
# 0    12.482347
# Name: label, dtype: float64

# %% [raw]
# This is the Classification problem and our Target feature have imbalanced data
# 87.51% entries for 1 who returned the loan
# 12.48% entries for 0 who didnt returned the loan

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# ### msisdn: mobile number of user

# %%
df['msisdn'].nunique()
# Out:
# 186243

# %%
df.shape
# Out:
# (209592, 36)

# %%
df[df['msisdn'].duplicated()]
# Out:
#         label       msisdn            aon  daily_decr30  daily_decr90  \
# 1903        1  09901I95206     138.000000    900.000000    900.000000
# 2281        1  14791I90583    1659.000000    124.754667    124.754667
# 2396        1  70401I85339    1419.000000    616.160000    619.100000
# 2910        1  40881I89238     108.000000     96.616000     96.616000
# 3675        1  41251I91190     363.000000   8615.000000   8713.490000
# ...       ...          ...            ...           ...           ...
# 209577      1  70448I82734  811881.372822    149.760000    149.760000
# 209578      1  60261I84455    1007.000000   5079.832000   5104.540000
# 209587      1  60331I70370     254.000000  20079.157333  20228.090000
# 209590      1  95583I84455    1075.000000     36.936000     36.936000
# 209591      1  28556I85350    1013.000000  11843.111667  11904.350000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 1903      434.78    434.78                0.0                0.0
# 2281      813.45    813.45                1.0                0.0
# 2396      556.88    589.76                1.0                0.0
# 2910      674.83    674.83               48.0                0.0
# 3675      498.81   2356.11                5.0                0.0
# ...          ...       ...                ...                ...
# 209577    922.20    922.20                4.0                0.0
# 209578   2844.84   3064.68                2.0                0.0
# 209587   4003.12   5173.74                2.0                0.0
# 209590   1728.36   1728.36                4.0                0.0
# 209591   5861.83   8893.20                3.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# 1903                   0              0           0.0                0.0
# 2281                4048              5           0.0             9612.0
# 2396                 773              5           6.0             6160.0
# 2910               11327              0           0.0                0.0
# 3675                 770              4           9.0             3849.0
# ...                  ...            ...           ...                ...
# 209577             12500              3           9.0            26567.0
# 209578              1539             10           3.0            11560.0
# 209587              1539              9           4.0            17243.0
# 209590               773              4           1.0             3092.0
# 209591              1539              5           8.0             9334.0
#
#         medianamnt_ma_rech30  medianmarechprebal30  cnt_ma_rech90  \
# 1903                     0.0                  0.00              0
# 2281                  2309.0                 16.07              6
# 2396                  1539.0                 32.00              6
# 2910                     0.0                  0.00              1
# 3675                   770.0                 27.50             10
# ...                      ...                   ...            ...
# 209577               10000.0                161.00              3
# 209578                1156.0                 68.70             15
# 209587                1547.0                 37.00             17
# 209590                 773.0                161.30              6
# 209591                1539.0                 51.13             11
#
#         fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 1903               0                  0                   0.0
# 2281              31              11332                2014.5
# 2396              53               6933                1156.0
# 2910               0              11327               11327.0
# 3675               2              12499                1539.0
# ...              ...                ...                   ...
# 209577             9              26567               10000.0
# 209578             3              16191                 773.0
# 209587             2              33719                1547.0
# 209590             2               4038                 773.0
# 209591             5              18592                1539.0
#
#         medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 1903                    0.00            0.0           0.0              0
# 2281                   19.57            0.0           0.0              0
# 2396                   44.50            0.0           0.0              0
# 2910                   43.00            0.0           0.0              0
# 3675                   28.00            0.0           0.0              0
# ...                      ...            ...           ...            ...
# 209577                161.00            0.0           0.0              0
# 209578                 69.20            0.0           0.0              0
# 209587                 37.00            0.0           0.0              0
# 209590                111.80            0.0           0.0              0
# 209591                 47.13            0.0           0.0              0
#
#         fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 1903               0            1             6              6.0
# 2281               0            3            18              6.0
# 2396               0            4            24              6.0
# 2910               0            2            12              6.0
# 3675               0            4            24              6.0
# ...              ...          ...           ...              ...
# 209577             0            2            12              6.0
# 209578             0            6            36              6.0
# 209587             0            6            66             12.0
# 209590             0            3            18              6.0
# 209591             0            4            42             12.0
#
#         medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 1903                   0.0          1.0             6                6
# 2281                   0.0          3.0            18                6
# 2396                   0.5          4.0            24                6
# 2910                   0.0          2.0            12                6
# 3675                   0.0          8.0            48                6
# ...                    ...          ...           ...              ...
# 209577                 0.0          2.0            12                6
# 209578                 0.0          6.0            36                6
# 209587                 0.0         15.0           120               12
# 209590                 0.0          3.0            18                6
# 209591                 0.0          6.0            54               12
#
#         medianamnt_loans90  payback30  payback90 pcircle       pdate
# 1903                   0.0   0.000000   0.000000     UPW  2016-08-17
# 2281                   0.0   2.333333   2.333333     UPW  2016-06-11
# 2396                   0.5   8.500000   8.500000     UPW  2016-07-02
# 2910                   0.0   0.000000   0.000000     UPW  2016-06-13
# 3675                   0.0   4.666667   4.000000     UPW  2016-08-01
# ...                    ...        ...        ...     ...         ...
# 209577                 0.0   5.500000   5.500000     UPW  2016-06-15
# 209578                 0.0   1.600000   1.600000     UPW  2016-07-06
# 209587                 0.0   3.000000   2.400000     UPW  2016-07-22
# 209590                 0.0   1.000000   1.000000     UPW  2016-06-12
# 209591                 0.0   4.000000   3.833333     UPW  2016-07-29
#
# [23349 rows x 36 columns]

# %% [markdown]
# ### aon : age on cellular network in days

# %% [markdown]
# ### Data Distribution plot

# %%
sns.distplot(df['aon'])
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Density'>

# %% [markdown]
# ### Box Plot

# %%
sns.boxplot(df['aon'])
# Out:
# <AxesSubplot:xlabel='aon'>

# %%
sns.barplot(df['label'], df['aon'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='aon'>

# %%
sns.distplot(df[df['label']==0]['aon'], hist=False)
sns.distplot(df[df['label']==1]['aon'], hist=False)
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Density'>

# %%
# Data is right skewed

# %%
df['aon'].min()
# Out:
# 1.0

# %% [markdown]
# ### daily_decr30 : Daily amount spent from main account, averaged over last 30 days (in Indonesian Rupiah)

# %%
sns.distplot(df['daily_decr30'])
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='Density'>

# %%
# Data is Right skewed with some negative values

# %%
sns.barplot(df['label'], df['daily_decr30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='daily_decr30'>

# %%
# Who spent average more money are tends to return loan amount

# %% [markdown]
# ## daily_decr90

# %%
sns.distplot(df['daily_decr90'])
# Out:
# <AxesSubplot:xlabel='daily_decr90', ylabel='Density'>

# %%
# Right skewed data

# %%
sns.barplot(df['label'], df['daily_decr90'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='daily_decr90'>

# %%
# Who spent average more money are tends to return loan amount

# %%
sns.scatterplot(df['daily_decr30'],df['daily_decr90'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='daily_decr90'>

# %% [raw]
# average amount spend in 30 days have linear relationship with average amount spent in 90 days as well.
#
# who has spent more money in average are tends to return loan amount

# %% [markdown]
# ### rental30 : Average main account balance over last 30 days

# %%
sns.distplot(df['rental30'])
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='Density'>

# %%
# Right skewed data

# %%
sns.barplot(df['label'], df['rental30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='rental30'>

# %%
# Users had average balance are tends to return loan amount more

# %% [markdown]
# ### rental90 :Average main account balance over last 90 days

# %%
sns.distplot(df['rental90'])
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='Density'>

# %%
# Right skewed data

# %%
plt.figure(figsize=(12,8))
sns.distplot(df['rental30'],color='red')
sns.distplot(df['rental90'],color='blue')
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='Density'>

# %%
sns.barplot(df['label'], df['rental90'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='rental90'>

# %%
# users has /maintained average balance are tends to return loan amount

# %%
sns.scatterplot(df['rental30'],df['rental90'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='rental90'>

# %% [raw]
# rental 30 and rental 90 have a linear relationship.
# if someone have maintained average balance in last 30 days he has managed it for 90 days as well
#
# whosoever has managed average balance have returned loan amount

# %% [markdown]
# ### last_rech_date_ma : Number of days till last recharge of main account

# %%
sns.distplot(df['last_rech_date_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='Density'>

# %%
sns.barplot(df['label'], df['last_rech_date_ma'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='last_rech_date_ma'>

# %% [markdown]
# ### last_rech_date_da : Number of days till last recharge of data account

# %%
sns.distplot(df['last_rech_date_da'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_da', ylabel='Density'>

# %%
# right skewed data

# %%
sns.barplot(df['label'],df['last_rech_date_da'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='last_rech_date_da'>

# %%
sns.scatterplot(df['last_rech_date_da'], df['last_rech_date_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_date_da', ylabel='last_rech_date_ma'>

# %% [raw]
# # Mostly users have 0 days for last recharge for main balance and data balance
#
# Few users who have not recharged main balance for many days also not recharged for data balance as well

# %%
df['last_rech_date_da'].value_counts()
# Out:
# 0.000000         202860
# 7.000000            163
# 8.000000            161
# 11.000000           150
# 13.000000           148
#                   ...
# 505559.452693         1
# 528847.562615         1
# 792111.278512         1
# 533972.466597         1
# 636529.127252         1
# Name: last_rech_date_da, Length: 1163, dtype: int64

# %% [markdown]
# ### last_rech_amt_ma : Amount of last recharge of main account (in Indonesian Rupiah)

# %%
sns.distplot(df['last_rech_amt_ma'])
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='Density'>

# %% [raw]
# Right skewed data

# %%
sns.barplot(df['label'],df['last_rech_amt_ma'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='last_rech_amt_ma'>

# %%
# WHo recharge with more average amount are tends to return loan amount

# %% [markdown]
# ### cnt_ma_rech30 : Number of times main account got recharged in last 30 days

# %%
sns.distplot(df['cnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='Density'>

# %%
sns.barplot(df['label'],df['cnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='cnt_ma_rech30'>

# %%
df['cnt_ma_rech30'].unique()
# Out:
# array([  2,   1,   0,   7,   4,   3,   5,  15,   6,   9,  10,  11,  13,
#          8,  12,  16,  18,  19,  29,  17,  14,  21,  27,  22,  37,  23,
#         20,  26,  25,  24,  34,  28,  32,  35,  31,  33,  40,  30,  41,
#         36,  52,  38,  48,  61,  39,  54,  84,  42,  44,  46,  45,  47,
#         49,  43,  55,  74,  58,  64,  59,  53,  51,  77,  78,  50,  91,
#         99, 115, 203,  60,  71,  63], dtype=int64)

# %% [markdown]
# ### fr_ma_rech30 : Frequency of main account recharged in last 30 days

# %%
sns.distplot(df['fr_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='Density'>

# %%
sns.barplot(df['label'],df['fr_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='fr_ma_rech30'>

# %% [raw]
# cnt_ma_rech30
# fr_ma_rech30
# sumamnt_ma_rech30
# medianamnt_ma_rech30
# medianmarechprebal30

# %%
df[['cnt_ma_rech30','fr_ma_rech30','sumamnt_ma_rech30','medianamnt_ma_rech30','medianmarechprebal30']]
# Out:
#         cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 1                   2          21.0             3078.0                1539.0
# 2                   1           0.0             5787.0                5787.0
# 3                   1           0.0             1539.0                1539.0
# 4                   0           0.0                0.0                   0.0
# 5                   7           2.0            20029.0                2309.0
# ...               ...           ...                ...                   ...
# 209589              3           2.0            10404.0                3178.0
# 209590              4           1.0             3092.0                 773.0
# 209591              5           8.0             9334.0                1539.0
# 209592              5           4.0            12154.0                 773.0
# 209593              2           1.0             9065.0                4532.5
#
#         medianmarechprebal30
# 1                       7.50
# 2                      61.04
# 3                      66.32
# 4                       0.00
# 5                      29.00
# ...                      ...
# 209589                 91.81
# 209590                161.30
# 209591                 51.13
# 209592                164.00
# 209593                356.70
#
# [209592 rows x 5 columns]

# %%
sns.scatterplot(df['cnt_ma_rech30'],df['fr_ma_rech30'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='fr_ma_rech30'>

# %% [markdown]
# ### sumamnt_ma_rech30 : Total amount of recharge in main account over last 30 days (in Indonesian Rupiah)

# %%
sns.distplot(df['sumamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='Density'>

# %% [raw]
# Right skewed data

# %%
sns.barplot(df['label'],df['sumamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='sumamnt_ma_rech30'>

# %% [markdown]
# Users amount of recharge is more which more likely to return loan amount

# %%
sns.scatterplot(df['cnt_ma_rech30'], df['sumamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='sumamnt_ma_rech30'>

# %% [markdown]
# Number of times main account got recahrged have linear relation with total amount

# %%
sns.scatterplot(df['fr_ma_rech30'], df['sumamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='sumamnt_ma_rech30'>

# %% [markdown]
# ### medianamnt_ma_rech30 : Median of amount of recharges done in main account over last 30 days at user level (in Indonesian Rupiah)

# %%
sns.distplot(df['medianamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='Density'>

# %% [markdown]
# Right skewed data

# %%
sns.barplot(df['label'],df['medianamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='medianamnt_ma_rech30'>

# %% [markdown]
# Users recharge with large amount are tends to return loan amount as well

# %%
sns.scatterplot(df['sumamnt_ma_rech30'],df['medianamnt_ma_rech30'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='medianamnt_ma_rech30'>

# %% [markdown]
# median amount of recharge is having linera relationship with total amount

# %% [markdown]
# ### no of times monthly recharge  vs  amount of recharge

# %%
sns.scatterplot(df['cnt_ma_rech30'], df['medianamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='medianamnt_ma_rech30'>

# %% [markdown]
# users who recharge main account many times mostly recharge with small amount whereas
# who recharged few times have recharged with large amount

# %% [markdown]
# ## medianmarechprebal30 : Median of main account balance just before recharge in last 30 days at user level (in Indonesian Rupiah)

# %%
sns.distplot(df['medianmarechprebal30'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='Density'>

# %%
# Right skewed data

# %%
sns.barplot(df['label'], df['medianmarechprebal30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='medianmarechprebal30'>

# %% [markdown]
# who had remaining balance in main account are less tends to retirn loan amount

# %%
sns.scatterplot(df['medianmarechprebal30'], df['sumamnt_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='sumamnt_ma_rech30'>

# %%
who had balance remaining they recharged mobile less. moreover they used the remaining balance
# Out:
# No variables match your requested type.

# %%
df[['cnt_ma_rech30','fr_ma_rech30','sumamnt_ma_rech30','medianamnt_ma_rech30','medianmarechprebal30']]
# Out:
#         cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 1                   2          21.0             3078.0                1539.0
# 2                   1           0.0             5787.0                5787.0
# 3                   1           0.0             1539.0                1539.0
# 4                   0           0.0                0.0                   0.0
# 5                   7           2.0            20029.0                2309.0
# ...               ...           ...                ...                   ...
# 209589              3           2.0            10404.0                3178.0
# 209590              4           1.0             3092.0                 773.0
# 209591              5           8.0             9334.0                1539.0
# 209592              5           4.0            12154.0                 773.0
# 209593              2           1.0             9065.0                4532.5
#
#         medianmarechprebal30
# 1                       7.50
# 2                      61.04
# 3                      66.32
# 4                       0.00
# 5                      29.00
# ...                      ...
# 209589                 91.81
# 209590                161.30
# 209591                 51.13
# 209592                164.00
# 209593                356.70
#
# [209592 rows x 5 columns]

# %% [markdown]
# # 90 Days details

# %% [markdown]
# ## cnt_ma_rech90 : Number of times main account got recharged in last 90 days

# %%
sns.distplot(df['cnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90', ylabel='Density'>

# %%
sns.scatterplot(df['cnt_ma_rech90'], df['cnt_ma_rech30'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech90', ylabel='cnt_ma_rech30'>

# %% [markdown]
# count of recharge in last 30 days have liner relationship with count of recharge in 90 days

# %% [markdown]
# ### fr_ma_rech90 : Frequency of main account recharged in last 90 days

# %%
sns.distplot(df['fr_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech90', ylabel='Density'>

# %% [markdown]
# Right skewed data

# %%
sns.barplot(df['label'], df['fr_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='fr_ma_rech90'>

# %%
sns.scatterplot(df['fr_ma_rech30'], df['fr_ma_rech90'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='fr_ma_rech90'>

# %% [markdown]
# Users who have 0 frequency in last 30 days and good frequency in last 90 days

# %% [markdown]
# ### sumamnt_ma_rech90 : Total amount of recharge in main account over last 90 days (in Indonasian Rupiah)

# %%
sns.distplot(df['sumamnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech90', ylabel='Density'>

# %%
sns.scatterplot(df['sumamnt_ma_rech30'], df['sumamnt_ma_rech90'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='sumamnt_ma_rech90'>

# %% [markdown]
# amount of monthly recharge in last 30 days have linear relation with amount of recharge in last 90 days

# %% [markdown]
# ### medianamnt_ma_rech90 : Median of amount of recharges done in main account over last 90 days at user level (in Indonasian Rupiah)

# %%
sns.scatterplot(df['medianamnt_ma_rech30'], df['medianamnt_ma_rech90'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='medianamnt_ma_rech90'>

# %% [markdown]
# as the median amount of recharge in last 30 days increases, median amount of recharge in 90 days also increases

# %% [markdown]
# ### medianmarechprebal90 : Median of main account balance just before recharge in last 90 days at user level (in Indonasian Rupiah)

# %%
sns.distplot(df['medianmarechprebal90'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal90', ylabel='Density'>

# %% [markdown]
# Right skewed data

# %%
sns.scatterplot(df['medianmarechprebal30'], df['medianmarechprebal90'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='medianmarechprebal90'>

# %% [markdown]
# who has balance 0 before 30 days recharge, had balance before 90 days recahrge

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# ## cnt_da_rech30 : Number of times data account got recharged in last 30 days

# %%
sns.distplot(df['cnt_da_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech30', ylabel='Density'>

# %% [markdown]
# Right skewed data

# %%
sns.barplot(df['label'],df['cnt_da_rech30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='cnt_da_rech30'>

# %% [markdown]
# ### count of main balance recharge vs count of data recharge in last 30 days

# %%
sns.scatterplot(df['cnt_ma_rech30'],df['cnt_da_rech30'])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='cnt_da_rech30'>

# %%
# Many user are who have recharged for data but not the main balance.

# %% [markdown]
# ### fr_da_rech30 : Frequency of data account recharged in last 30 days

# %%
sns.distplot(df['fr_da_rech30'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech30', ylabel='Density'>

# %% [markdown]
# ### frequency of main balance recharge vs frequency of data recharge in last 30 days

# %%
sns.scatterplot(df['fr_da_rech30'], df['fr_ma_rech30'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech30', ylabel='fr_ma_rech30'>

# %% [markdown]
# ## cnt_da_rech90 : Number of times data account got recharged in last 90 days

# %%
sns.distplot(df['cnt_da_rech90'])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech90', ylabel='Density'>

# %%
sns.barplot(df['label'],df['cnt_da_rech90'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='cnt_da_rech90'>

# %%
sns.scatterplot(df['cnt_da_rech90'], df['cnt_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='cnt_da_rech90', ylabel='cnt_ma_rech90'>

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pcircle', 'pdate'],
#       dtype='object')

# %% [markdown]
# ### fr_da_rech90 : Frequency of data account recharged in last 90 days

# %%
sns.distplot(df['fr_da_rech90'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech90', ylabel='Density'>

# %%
sns.scatterplot(df['fr_da_rech90'], df['fr_ma_rech90'])
# Out:
# <AxesSubplot:xlabel='fr_da_rech90', ylabel='fr_ma_rech90'>

# %% [markdown]
# ### cnt_loans30 : Number of loans taken by user in last 30 days

# %%
sns.distplot(df['cnt_loans30'])
# Out:
# <AxesSubplot:xlabel='cnt_loans30', ylabel='Density'>

# %%
sns.barplot(df['label'],df['cnt_loans30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='cnt_loans30'>

# %%
# users have taken more loan in last 30 days are tends to repay loan

# %%
sns.scatterplot(df['aon'], df['cnt_loans30'], hue=df['label'])
# Out:
# <AxesSubplot:xlabel='aon', ylabel='cnt_loans30'>

# %% [markdown]
# mostly new users have taken loan

# %% [markdown]
# ## amnt_loans30	Total amount of loans taken by user in last 30 days

# %%
sns.distplot(df['amnt_loans30'])
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='Density'>

# %%
sns.barplot(df['label'],df['amnt_loans30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='amnt_loans30'>

# %% [markdown]
# who has taken more amount loan has repayed the loan

# %% [markdown]
# ## maxamnt_loans30	maximum amount of loan taken by the user in last 30 days

# %%
sns.distplot(df['maxamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='Density'>

# %%
sns.barplot(df['label'],df['maxamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='maxamnt_loans30'>

# %%
sns.scatterplot(df['maxamnt_loans30'], df['amnt_loans30'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='amnt_loans30'>

# %% [markdown]
# ## medianamnt_loans30	Median of amounts of loan taken by the user in last 30 days

# %%
sns.distplot(df['medianamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='Density'>

# %%
df['medianamnt_loans30'].unique()
# Out:
# array([0. , 1. , 0.5, 2. , 1.5, 3. ])

# %% [markdown]
# ## cnt_loans90	Number of loans taken by user in last 90 days

# %%
sns.distplot(df['cnt_loans90'])
# Out:
# <AxesSubplot:xlabel='cnt_loans90', ylabel='Density'>

# %%
sns.scatterplot(df['cnt_loans90'],df['cnt_loans30'])
# Out:
# <AxesSubplot:xlabel='cnt_loans90', ylabel='cnt_loans30'>

# %% [markdown]
# ## amnt_loans90	Total amount of loans taken by user in last 90 days

# %%
sns.distplot(df['amnt_loans90'])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='Density'>

# %%
sns.barplot(df['label'], df['amnt_loans90'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='amnt_loans90'>

# %% [markdown]
# who has taken more amount loan have returned loan

# %%
sns.scatterplot(df['amnt_loans30'],df['amnt_loans90'], hue=df['label'] )
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='amnt_loans90'>

# %% [markdown]
# amount loan in 30 days have linear relationship with loan amount in 90 days

# %% [markdown]
# ## maxamnt_loans30	maximum amount of loan taken by the user in last 30 days

# %%
sns.distplot(df['maxamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='Density'>

# %%
sns.barplot(df['label'], df['maxamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='maxamnt_loans30'>

# %%
df['maxamnt_loans30'].unique()
# Out:
# array([6.00000000e+00, 1.20000000e+01, 0.00000000e+00, ...,
#        9.28645017e+04, 5.42592657e+04, 9.69272433e+04])

# %%
df['maxamnt_loans30'].values
# Out:
# array([ 6., 12.,  6., ..., 12., 12., 12.])

# %% [markdown]
# ## medianamnt_loans30	Median of amounts of loan taken by the user in last 30 days

# %%
sns.distplot(df['medianamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='Density'>

# %%
df['medianamnt_loans30'].values
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
df['medianamnt_loans30'].unique()
# Out:
# array([0. , 1. , 0.5, 2. , 1.5, 3. ])

# %% [markdown]
# ## cnt_loans90	Number of loans taken by user in last 90 days

# %%
sns.distplot(df['cnt_loans90'])
# Out:
# <AxesSubplot:xlabel='cnt_loans90', ylabel='Density'>

# %%
sns.scatterplot(df['cnt_loans90'], df['cnt_loans30'])
# Out:
# <AxesSubplot:xlabel='cnt_loans90', ylabel='cnt_loans30'>

# %% [markdown]
# ## amnt_loans90	Total amount of loans taken by user in last 90 days

# %%
sns.distplot(df['amnt_loans90'])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='Density'>

# %%
sns.scatterplot(df['amnt_loans30'], df['amnt_loans90'])
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='amnt_loans90'>

# %% [markdown]
# ## maxamnt_loans90	maximum amount of loan taken by the user in last 90 days

# %%
sns.distplot(df['maxamnt_loans90'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='Density'>

# %%
df['maxamnt_loans90'].value_counts()
# Out:
# 6     180944
# 12     26605
# 0       2043
# Name: maxamnt_loans90, dtype: int64

# %%
sns.scatterplot(df['maxamnt_loans90'], df['maxamnt_loans30'])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='maxamnt_loans30'>

# %% [markdown]
# ## medianamnt_loans90	Median of amounts of loan taken by the user in last 90 days

# %%
sns.distplot(df['medianamnt_loans90'])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans90', ylabel='Density'>

# %%
df['medianamnt_loans90'].value_counts()
# Out:
# 0.0    197423
# 1.0      6172
# 0.5      5668
# 2.0       307
# 1.5        19
# 3.0         3
# Name: medianamnt_loans90, dtype: int64

# %% [markdown]
# ## payback30	Average payback time in days over last 30 days

# %%
sns.distplot(df['payback30'])
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='Density'>

# %%
sns.barplot(df['label'], df['payback30'])
# Out:
# <AxesSubplot:xlabel='label', ylabel='payback30'>

# %% [markdown]
# ## payback90	Average payback time in days over last 90 days

# %%
sns.distplot(df['payback90'])
# Out:
# <AxesSubplot:xlabel='payback90', ylabel='Density'>

# %%
sns.scatterplot(df['payback30'], df['payback90'])
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='payback90'>

# %% [markdown]
# ## pcircle	telecom circle

# %%
sns.countplot(df['pcircle'])
# Out:
# <AxesSubplot:xlabel='pcircle', ylabel='count'>

# %%
df['pcircle'].unique()
# Out:
# array(['UPW'], dtype=object)

# %%
df['pcircle'].value_counts()
# Out:
# UPW    209592
# Name: pcircle, dtype: int64

# %% [markdown]
# ## pdate	date

# %%
df['pdate'].value_counts()
# Out:
# 2016-07-04    3150
# 2016-07-05    3127
# 2016-07-07    3116
# 2016-06-20    3099
# 2016-06-17    3082
#               ...
# 2016-06-04    1559
# 2016-08-18    1407
# 2016-08-19    1132
# 2016-08-20     788
# 2016-08-21     324
# Name: pdate, Length: 82, dtype: int64

# %%
df.head(3)
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 1      0  21408I70789  272.0       3055.05       3065.15    220.13    260.13
# 2      1  76462I70374  712.0      12122.00      12124.75   3691.26   3691.26
# 3      1  17943I70372  535.0       1398.00       1398.00    900.13    900.13
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 1                2.0                0.0              1539              2
# 2               20.0                0.0              5787              1
# 3                3.0                0.0              1539              1
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 1          21.0             3078.0                1539.0
# 2           0.0             5787.0                5787.0
# 3           0.0             1539.0                1539.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 1                  7.50              2            21               3078
# 2                 61.04              1             0               5787
# 3                 66.32              1             0               1539
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 1                1539.0                  7.50            0.0           0.0
# 2                5787.0                 61.04            0.0           0.0
# 3                1539.0                 66.32            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 1              0             0            2            12              6.0
# 2              0             0            1            12             12.0
# 3              0             0            1             6              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 1                 0.0          2.0            12                6
# 2                 0.0          1.0            12               12
# 3                 0.0          1.0             6                6
#
#    medianamnt_loans90  payback30  payback90 pcircle       pdate
# 1                 0.0       29.0       29.0     UPW  2016-07-20
# 2                 0.0        0.0        0.0     UPW  2016-08-10
# 3                 0.0        0.0        0.0     UPW  2016-08-19

# %%
# msisdn is mobile number which will not add any usefull insights to our prediction, so deop it
# pcircle has only 1 type of value allover in all records which will not add any usefull insights for our prediction so drop it as well

# %%
df=df.drop(['msisdn','pcircle'], axis=1)

# %%
df.shape
# Out:
# (209592, 34)

# %% [markdown]
# # Correlation

# %%
X=df.iloc[:,1:]
Y= df.iloc[:,0]
correlation_data= pd.concat([X,Y], axis=1)

# %%
plt.figure(figsize=(20,15))
sns.heatmap(correlation_data.corr(), annot=True,linewidths=.05,linecolor='white')
# Out:
# <AxesSubplot:>

# %%
correlation_data.corr()['label']
# Out:
# aon                    -0.003787
# daily_decr30            0.168294
# daily_decr90            0.166147
# rental30                0.058645
# rental90                0.076034
# last_rech_date_ma       0.003730
# last_rech_date_da       0.001711
# last_rech_amt_ma        0.131805
# cnt_ma_rech30           0.237331
# fr_ma_rech30            0.001330
# sumamnt_ma_rech30       0.202828
# medianamnt_ma_rech30    0.141491
# medianmarechprebal30   -0.004842
# cnt_ma_rech90           0.236393
# fr_ma_rech90            0.084386
# sumamnt_ma_rech90       0.205794
# medianamnt_ma_rech90    0.120855
# medianmarechprebal90    0.037126
# cnt_da_rech30           0.003827
# fr_da_rech30           -0.000026
# cnt_da_rech90           0.002999
# fr_da_rech90           -0.005418
# cnt_loans30             0.196283
# amnt_loans30            0.197272
# maxamnt_loans30         0.000248
# medianamnt_loans30      0.044590
# cnt_loans90             0.004733
# amnt_loans90            0.199788
# maxamnt_loans90         0.084144
# medianamnt_loans90      0.035747
# payback30               0.048330
# payback90               0.049178
# label                   1.000000
# Name: label, dtype: float64

# %% [markdown]
# # independent features are neither highly correlated nor low correlated with target feature
# # But we can see multicollinearity issues as many independent features are highly correlated with each other

# %% [markdown]
# Lets extract information from date feature

# %%
df.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 1      0  272.0   3055.050000   3065.150000    220.13    260.13
# 2      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 3      1  535.0   1398.000000   1398.000000    900.13    900.13
# 4      1  241.0     21.228000     21.228000    159.42    159.42
# 5      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 1                2.0                0.0              1539              2
# 2               20.0                0.0              5787              1
# 3                3.0                0.0              1539              1
# 4               41.0                0.0               947              0
# 5                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 1          21.0             3078.0                1539.0
# 2           0.0             5787.0                5787.0
# 3           0.0             1539.0                1539.0
# 4           0.0                0.0                   0.0
# 5           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 1                  7.50              2            21               3078
# 2                 61.04              1             0               5787
# 3                 66.32              1             0               1539
# 4                  0.00              1             0                947
# 5                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 1                1539.0                  7.50            0.0           0.0
# 2                5787.0                 61.04            0.0           0.0
# 3                1539.0                 66.32            0.0           0.0
# 4                 947.0                  2.50            0.0           0.0
# 5                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 1              0             0            2            12              6.0
# 2              0             0            1            12             12.0
# 3              0             0            1             6              6.0
# 4              0             0            2            12              6.0
# 5              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 1                 0.0          2.0            12                6
# 2                 0.0          1.0            12               12
# 3                 0.0          1.0             6                6
# 4                 0.0          2.0            12                6
# 5                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90       pdate
# 1                 0.0  29.000000  29.000000  2016-07-20
# 2                 0.0   0.000000   0.000000  2016-08-10
# 3                 0.0   0.000000   0.000000  2016-08-19
# 4                 0.0   0.000000   0.000000  2016-06-06
# 5                 0.0   2.333333   2.333333  2016-06-22

# %%
df['pdate']=pd.to_datetime(df['pdate'])

# %%
df.dtypes
# Out:
# label                            int64
# aon                            float64
# daily_decr30                   float64
# daily_decr90                   float64
# rental30                       float64
# rental90                       float64
# last_rech_date_ma              float64
# last_rech_date_da              float64
# last_rech_amt_ma                 int64
# cnt_ma_rech30                    int64
# fr_ma_rech30                   float64
# sumamnt_ma_rech30              float64
# medianamnt_ma_rech30           float64
# medianmarechprebal30           float64
# cnt_ma_rech90                    int64
# fr_ma_rech90                     int64
# sumamnt_ma_rech90                int64
# medianamnt_ma_rech90           float64
# medianmarechprebal90           float64
# cnt_da_rech30                  float64
# fr_da_rech30                   float64
# cnt_da_rech90                    int64
# fr_da_rech90                     int64
# cnt_loans30                      int64
# amnt_loans30                     int64
# maxamnt_loans30                float64
# medianamnt_loans30             float64
# cnt_loans90                    float64
# amnt_loans90                     int64
# maxamnt_loans90                  int64
# medianamnt_loans90             float64
# payback30                      float64
# payback90                      float64
# pdate                   datetime64[ns]
# dtype: object

# %%
df['pdate'].dt.year.unique()
# Out:
# array([2016], dtype=int64)

# %%
df['pdate'].dt.month.unique()
# Out:
# array([7, 8, 6], dtype=int64)

# %%
df['pdate'].dt.month_name().unique()
# Out:
# array(['July', 'August', 'June'], dtype=object)

# %%
df['pdate'].dt.day.unique()
# Out:
# array([20, 10, 19,  6, 22,  2,  5, 15,  8, 12, 29, 16,  3, 24,  4,  1, 26,
#        23,  9,  7, 27, 11, 30, 14, 21, 25, 28, 18, 13, 17, 31],
#       dtype=int64)

# %%
# pdate give us insight that all data of year  2016 only and of month July August June only
# dates are of all month dates 1-31

# %%
df['month']=df['pdate'].dt.month_name()
df['day']=df['pdate'].dt.day

# %% [markdown]
# we have extracted month and day for the date feature, now we can delete date feature

# %%
df.drop('pdate', axis=1, inplace=True)

# %%
df.head()
# Out:
#    label    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 1      0  272.0   3055.050000   3065.150000    220.13    260.13
# 2      1  712.0  12122.000000  12124.750000   3691.26   3691.26
# 3      1  535.0   1398.000000   1398.000000    900.13    900.13
# 4      1  241.0     21.228000     21.228000    159.42    159.42
# 5      1  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 1                2.0                0.0              1539              2
# 2               20.0                0.0              5787              1
# 3                3.0                0.0              1539              1
# 4               41.0                0.0               947              0
# 5                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# 1          21.0             3078.0                1539.0
# 2           0.0             5787.0                5787.0
# 3           0.0             1539.0                1539.0
# 4           0.0                0.0                   0.0
# 5           2.0            20029.0                2309.0
#
#    medianmarechprebal30  cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  \
# 1                  7.50              2            21               3078
# 2                 61.04              1             0               5787
# 3                 66.32              1             0               1539
# 4                  0.00              1             0                947
# 5                 29.00              8             2              23496
#
#    medianamnt_ma_rech90  medianmarechprebal90  cnt_da_rech30  fr_da_rech30  \
# 1                1539.0                  7.50            0.0           0.0
# 2                5787.0                 61.04            0.0           0.0
# 3                1539.0                 66.32            0.0           0.0
# 4                 947.0                  2.50            0.0           0.0
# 5                2888.0                 35.00            0.0           0.0
#
#    cnt_da_rech90  fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 1              0             0            2            12              6.0
# 2              0             0            1            12             12.0
# 3              0             0            1             6              6.0
# 4              0             0            2            12              6.0
# 5              0             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 1                 0.0          2.0            12                6
# 2                 0.0          1.0            12               12
# 3                 0.0          1.0             6                6
# 4                 0.0          2.0            12                6
# 5                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90   month  day
# 1                 0.0  29.000000  29.000000    July   20
# 2                 0.0   0.000000   0.000000  August   10
# 3                 0.0   0.000000   0.000000  August   19
# 4                 0.0   0.000000   0.000000    June    6
# 5                 0.0   2.333333   2.333333    June   22

# %% [markdown]
# ## Seprate dependent and independent features

# %%
X= df.iloc[:,1:]
Y= df.iloc[:,0]

# %%
X.shape , Y.shape
# Out:
# ((209592, 34), (209592,))

# %%
X.head(10)
# Out:
#        aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 1    272.0   3055.050000   3065.150000    220.13    260.13                2.0
# 2    712.0  12122.000000  12124.750000   3691.26   3691.26               20.0
# 3    535.0   1398.000000   1398.000000    900.13    900.13                3.0
# 4    241.0     21.228000     21.228000    159.42    159.42               41.0
# 5    947.0    150.619333    150.619333   1098.90   1098.90                4.0
# 6    568.0   2257.362667   2261.460000    368.13    380.13                2.0
# 7    545.0   2876.641667   2883.970000    335.75    402.90               13.0
# 8    768.0  12905.000000  17804.150000    900.35   2549.11                4.0
# 9   1191.0     90.695000     90.695000   2287.50   2287.50                1.0
# 10   536.0     29.357333     29.357333    612.96    612.96               11.0
#
#     last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 1                 0.0              1539              2          21.0
# 2                 0.0              5787              1           0.0
# 3                 0.0              1539              1           0.0
# 4                 0.0               947              0           0.0
# 5                 0.0              2309              7           2.0
# 6                 0.0              1539              4          10.0
# 7                 0.0              5787              1           0.0
# 8                55.0              3178              3           3.0
# 9                 0.0              1539              4           1.0
# 10                0.0               773              1           0.0
#
#     sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# 1              3078.0                1539.0                  7.50
# 2              5787.0                5787.0                 61.04
# 3              1539.0                1539.0                 66.32
# 4                 0.0                   0.0                  0.00
# 5             20029.0                2309.0                 29.00
# 6              6156.0                1539.0                 15.40
# 7              5787.0                5787.0                277.80
# 8             10404.0                3178.0                 36.00
# 9              6164.0                1539.0                 39.90
# 10              773.0                 773.0                 86.80
#
#     cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 1               2            21               3078                1539.0
# 2               1             0               5787                5787.0
# 3               1             0               1539                1539.0
# 4               1             0                947                 947.0
# 5               8             2              23496                2888.0
# 6               8             0              11744                1539.0
# 7               1             0               5787                5787.0
# 8               9             3              26095                3178.0
# 9               4             1               6164                1539.0
# 10              1             0                773                 773.0
#
#     medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 1                   7.50            0.0           0.0              0
# 2                  61.04            0.0           0.0              0
# 3                  66.32            0.0           0.0              0
# 4                   2.50            0.0           0.0              0
# 5                  35.00            0.0           0.0              0
# 6                  55.90            0.0           0.0              0
# 7                 277.80            0.0           0.0              0
# 8                  36.00            0.0           0.0              1
# 9                  39.90            0.0           0.0              0
# 10                 86.80            0.0           0.0              0
#
#     fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 1              0            2            12              6.0
# 2              0            1            12             12.0
# 3              0            1             6              6.0
# 4              0            2            12              6.0
# 5              0            7            42              6.0
# 6              0            3            18              6.0
# 7              0            1             6              6.0
# 8              0            3            18              6.0
# 9              0            4            24              6.0
# 10             0            1             6              6.0
#
#     medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 1                  0.0          2.0            12                6
# 2                  0.0          1.0            12               12
# 3                  0.0          1.0             6                6
# 4                  0.0          2.0            12                6
# 5                  0.0          7.0            42                6
# 6                  0.0          3.0            18                6
# 7                  0.0          1.0             6                6
# 8                  0.0          7.0            42                6
# 9                  0.0          4.0            24                6
# 10                 0.0          1.0             6                6
#
#     medianamnt_loans90  payback30  payback90   month  day
# 1                  0.0  29.000000  29.000000    July   20
# 2                  0.0   0.000000   0.000000  August   10
# 3                  0.0   0.000000   0.000000  August   19
# 4                  0.0   0.000000   0.000000    June    6
# 5                  0.0   2.333333   2.333333    June   22
# 6                  0.0  11.000000   8.333333    July    2
# 7                  0.0   0.000000   0.000000    July    5
# 8                  0.0   6.000000   3.857143  August    5
# 9                  0.0   2.666667   2.666667    June   15
# 10                 0.0   0.000000   0.000000    June    8

# %% [markdown]
# # outliers

# %% [markdown]
# as we have right skewed dataset , we will use IQR technique to handle outliers

# %%
X.skew()
# Out:
# aon                     10.392926
# daily_decr30             3.946235
# daily_decr90             4.252567
# rental30                 4.560502
# rental90                 4.467271
# last_rech_date_ma       14.790939
# last_rech_date_da       14.814821
# last_rech_amt_ma         3.781141
# cnt_ma_rech30            3.283838
# fr_ma_rech30            14.772797
# sumamnt_ma_rech30        6.386774
# medianamnt_ma_rech30     3.512314
# medianmarechprebal30    14.779847
# cnt_ma_rech90            3.425244
# fr_ma_rech90             2.285415
# sumamnt_ma_rech90        4.897937
# medianamnt_ma_rech90     3.752696
# medianmarechprebal90    45.086190
# cnt_da_rech30           17.818321
# fr_da_rech30            14.776395
# cnt_da_rech90           27.267213
# fr_da_rech90            28.988013
# cnt_loans30              2.713426
# amnt_loans30             2.975720
# maxamnt_loans30         17.658009
# medianamnt_loans30       4.551031
# cnt_loans90             16.594368
# amnt_loans90             3.149999
# maxamnt_loans90          1.678297
# medianamnt_loans90       4.895707
# payback30                8.311500
# payback90                6.900427
# day                      0.199856
# dtype: float64

# %%
# We have highly skewed dataset, Lets see boxplot

# %%
for i in [x for x in X.columns if X[x].dtypes!='O']:
    sns.distplot(X[i])
    plt.show()

# %%
for i in [x for x in X.columns if X[x].dtypes!='O']:
    sns.boxplot(X[i])
    plt.show()

# %%
# some features are of categorical nature.
X.head()
# Out:
#      aon  daily_decr30  daily_decr90  rental30  rental90  last_rech_date_ma  \
# 1  272.0   3055.050000   3065.150000    220.13    260.13                2.0
# 2  712.0  12122.000000  12124.750000   3691.26   3691.26               20.0
# 3  535.0   1398.000000   1398.000000    900.13    900.13                3.0
# 4  241.0     21.228000     21.228000    159.42    159.42               41.0
# 5  947.0    150.619333    150.619333   1098.90   1098.90                4.0
#
#    last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  \
# 1                0.0              1539              2          21.0
# 2                0.0              5787              1           0.0
# 3                0.0              1539              1           0.0
# 4                0.0               947              0           0.0
# 5                0.0              2309              7           2.0
#
#    sumamnt_ma_rech30  medianamnt_ma_rech30  medianmarechprebal30  \
# 1             3078.0                1539.0                  7.50
# 2             5787.0                5787.0                 61.04
# 3             1539.0                1539.0                 66.32
# 4                0.0                   0.0                  0.00
# 5            20029.0                2309.0                 29.00
#
#    cnt_ma_rech90  fr_ma_rech90  sumamnt_ma_rech90  medianamnt_ma_rech90  \
# 1              2            21               3078                1539.0
# 2              1             0               5787                5787.0
# 3              1             0               1539                1539.0
# 4              1             0                947                 947.0
# 5              8             2              23496                2888.0
#
#    medianmarechprebal90  cnt_da_rech30  fr_da_rech30  cnt_da_rech90  \
# 1                  7.50            0.0           0.0              0
# 2                 61.04            0.0           0.0              0
# 3                 66.32            0.0           0.0              0
# 4                  2.50            0.0           0.0              0
# 5                 35.00            0.0           0.0              0
#
#    fr_da_rech90  cnt_loans30  amnt_loans30  maxamnt_loans30  \
# 1             0            2            12              6.0
# 2             0            1            12             12.0
# 3             0            1             6              6.0
# 4             0            2            12              6.0
# 5             0            7            42              6.0
#
#    medianamnt_loans30  cnt_loans90  amnt_loans90  maxamnt_loans90  \
# 1                 0.0          2.0            12                6
# 2                 0.0          1.0            12               12
# 3                 0.0          1.0             6                6
# 4                 0.0          2.0            12                6
# 5                 0.0          7.0            42                6
#
#    medianamnt_loans90  payback30  payback90   month  day
# 1                 0.0  29.000000  29.000000    July   20
# 2                 0.0   0.000000   0.000000  August   10
# 3                 0.0   0.000000   0.000000  August   19
# 4                 0.0   0.000000   0.000000    June    6
# 5                 0.0   2.333333   2.333333    June   22

# %%
outlier=['aon',
 'daily_decr30',
 'daily_decr90',
 'rental30',
 'rental90',
 'last_rech_date_ma',
 'last_rech_date_da',
 'last_rech_amt_ma',
 'cnt_ma_rech30',
 'fr_ma_rech30',
 'sumamnt_ma_rech30',
 'medianamnt_ma_rech30',
 'medianmarechprebal30',
 'cnt_ma_rech90',
 'fr_ma_rech90',
 'sumamnt_ma_rech90',
 'medianamnt_ma_rech90',
 'medianmarechprebal90',
 'cnt_da_rech30',
 'fr_da_rech30',
 'cnt_da_rech90',
 'fr_da_rech90',
 'cnt_loans30',
 'amnt_loans30',
 'medianamnt_loans30',
 'cnt_loans90',
 'amnt_loans90',
 'maxamnt_loans90',
 'medianamnt_loans90',
 'payback30',
 'payback90',
  'day']

# %%
for i in outlier:
    IQR= X[i].quantile(.75)-X[i].quantile(.25)
    lower=X[i].quantile(.25) - (1.5 * IQR)
    upper=X[i].quantile(.75) + (1.5 * IQR)
    X[i]=np.where(X[i]<lower,lower,X[i])
    X[i]=np.where(X[i]>upper,upper,X[i])

# %%
X.skew()
# Out:
# aon                      0.952366
# daily_decr30             1.239247
# daily_decr90             1.238996
# rental30                 1.215459
# rental90                 1.210379
# last_rech_date_ma        1.133951
# last_rech_date_da        0.000000
# last_rech_amt_ma         1.003439
# cnt_ma_rech30            0.904162
# fr_ma_rech30             1.253275
# sumamnt_ma_rech30        1.080772
# medianamnt_ma_rech30     0.728218
# medianmarechprebal30     1.105335
# cnt_ma_rech90            0.934785
# fr_ma_rech90             1.172472
# sumamnt_ma_rech90        1.126415
# medianamnt_ma_rech90     0.763902
# medianmarechprebal90     1.083484
# cnt_da_rech30            0.000000
# fr_da_rech30             0.000000
# cnt_da_rech90            0.000000
# fr_da_rech90             0.000000
# cnt_loans30              1.340357
# amnt_loans30             1.231096
# maxamnt_loans30         17.658009
# medianamnt_loans30       0.000000
# cnt_loans90              1.281861
# amnt_loans90             1.217939
# maxamnt_loans90          0.000000
# medianamnt_loans90       0.000000
# payback30                1.189328
# payback90                1.170831
# day                      0.199856
# dtype: float64

# %%
# Handling outliers has handled skewness in data

# %% [markdown]
# ## Feature Selection through VIF

# %%
# To find out VIF, we have to scale complete data first
cont=X.drop('month', axis=1)
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
scaler=sc.fit_transform(cont)

# %%
scaler.shape
# Out:
# (209592, 33)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
VIF=pd.DataFrame()
VIF['features']= cont.columns
VIF['VIF']=[variance_inflation_factor(scaler,i) for i in range(len(cont.columns))]

# %%
VIF
# Out:
#                 features        VIF
# 0                    aon   1.023341
# 1           daily_decr30  54.139950
# 2           daily_decr90  58.690476
# 3               rental30  15.360020
# 4               rental90  17.094022
# 5      last_rech_date_ma   1.448586
# 6      last_rech_date_da        NaN
# 7       last_rech_amt_ma   3.730802
# 8          cnt_ma_rech30  15.471194
# 9           fr_ma_rech30   1.481602
# 10     sumamnt_ma_rech30  14.584664
# 11  medianamnt_ma_rech30   5.676217
# 12  medianmarechprebal30   3.361085
# 13         cnt_ma_rech90  17.383898
# 14          fr_ma_rech90   1.453528
# 15     sumamnt_ma_rech90  15.481175
# 16  medianamnt_ma_rech90   6.281437
# 17  medianmarechprebal90   3.297954
# 18         cnt_da_rech30        NaN
# 19          fr_da_rech30        NaN
# 20         cnt_da_rech90        NaN
# 21          fr_da_rech90        NaN
# 22           cnt_loans30  31.178010
# 23          amnt_loans30  35.563107
# 24       maxamnt_loans30   1.000104
# 25    medianamnt_loans30        NaN
# 26           cnt_loans90  24.225280
# 27          amnt_loans90  36.215404
# 28       maxamnt_loans90        NaN
# 29    medianamnt_loans90        NaN
# 30             payback30   3.720994
# 31             payback90   3.493725
# 32                   day   1.040539

# %%
# if VIF is more which means it can be explained by other variables very well so we do not require it
